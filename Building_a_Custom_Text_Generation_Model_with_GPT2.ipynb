# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 65.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 38.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 65.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 60.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 69.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi
# Out:
# Thu May 25 11:38:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# FINE-TUNING THE GPT-2 MODEL

# %%
from simpletransformers.language_modeling import LanguageModelingModel, LanguageModelingArgs

# %%
# Editing Configurations
model_args = LanguageModelingArgs()
model_args.reprocess_input_data = True
model_args.overwrite_output_dir = True
model_args.num_train_epochs = 15
model_args.best_model_dir = "outputs/best_model"
model_args.save_best_model =True
model_args.train_batch_size = 8
model_args.dataset_type = "simple"
model_args.mlm = False  # mlm must be False for CLM
model_args.vocab_size = 50257

# %% [markdown]
# Dataset types
# simple (or None) - Each line in the train file is considered to be a single, separate sample. sliding_window can be set to True to automatically split longer sequences into samples of length max_seq_length. Uses multiprocessing for significantly improved performance on multi-core systems.
#
# line_by_line - Treats each line in the train file as a separate sample. Uses tokenizers from the Hugging Face tokenizers library.
#
# text - Treats each line in the train file as a separate sample. Uses default tokenizers.
#
# Using simple is recommended.

# %%
train_file = "/content/train.txt"
test_file = "/content/test.txt"

#Language Model Loading it can either GPT2, BERT, ELECTRA etc.
model = LanguageModelingModel(
    "gpt2", "gpt2", args=model_args, train_files=train_file
)

# %%
# Train the model
model.train_model(train_file, eval_file=test_file)
# Out:
# ...
# Running Epoch 14 of 15:   0%|          | 0/1 [00:00<?, ?it/s]
# (15, 3.3988508065541585)

# %%
result= model.eval_model(test_file)
# Out:
# ...
# Running Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
result
# Out:
# {'eval_loss': 3.5228209495544434, 'perplexity': tensor(33.8799)}

# %% [markdown]
# Here we increase the epoch we will get less loss.

# %% [markdown]
# NEXT SENTENCE PREDICTION

# %%
from simpletransformers.language_generation import LanguageGenerationModel, LanguageGenerationArgs
Language_gen_args = LanguageGenerationArgs()
Language_gen_args.max_length = 100

# %%
model = LanguageGenerationModel("gpt2", "/content/outputs/checkpoint-15-epoch-15")
output = model.generate("Despite the recent successes of deep")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
output[0]
# Out:
# 'Despite the recent successes of deep learning, artificial intelligence and computer vision, they will continue to find more new and useful ways to develop'
